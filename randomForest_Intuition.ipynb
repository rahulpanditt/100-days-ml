# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['a','b','c','d','e'])
df['target']=y
df.head()
# Out:
#           a         b         c         d         e  target
# 0  0.463418  0.030722 -0.343536  1.351243  0.573291       1
# 1  1.767734  1.907874 -1.122585  0.771091  1.542618       1
# 2  0.645799  0.497108  0.033069 -2.844073 -2.086931       0
# 3  1.763190  0.669100 -0.450897 -0.274788 -1.944087       0
# 4  0.934518  0.679429 -2.306963 -0.269605 -0.561931       0

# %%
df.shape
# Out:
# (100, 6)

# %%
def sample_row(df,percent):
    return df.sample(int(df.shape[0]*percent))

# %%
import random
def sample_column(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1))) #random.sample(list, k): Selects k unique elements from the given list.
    df_new = df[cols]
    df_new['target'] = df['target']
    return df_new

# %%
def combined_sampling(df,row_percent,col_percent):
    new_df = sample_row(df,row_percent)
    return sample_column(new_df,col_percent)

# %%
sample_column(df,0.5)
# Out:
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']
#            a         e  target
# 0   0.463418  0.573291       1
# 1   1.767734  1.542618       1
# 2   0.645799 -2.086931       0
# 3   1.763190 -1.944087       0
# 4   0.934518 -0.561931       0
# ..       ...       ...     ...
# 95  1.327962 -1.571685       0
# 96  2.151113 -2.973955       0
# 97 -0.481233  0.038938       0
# 98  0.438720  2.655706       1
# 99 -0.395826  0.491639       0
#
# [100 rows x 3 columns]

# %%
sample_row(df,0.5)
# Out:
#            a         b         c         d         e  target
# 8  -0.272125 -0.127661  0.346858  1.515132  1.420700       1
# 1   1.767734  1.907874 -1.122585  0.771091  1.542618       1
# 66  1.526171 -1.485048 -0.333049 -0.649123 -1.137375       0
# 41 -1.052059  0.031052 -1.382596  1.593939  1.325438       1
# 48  1.335499  2.214649 -0.323279 -0.339356 -1.082921       0
# 32  1.122652  2.235628 -2.937428  2.156957 -0.232220       0
# 16  1.647982  2.693598 -1.076450  0.384761  1.346649       1
# 24  2.958457  2.820990  1.565527  2.432409 -2.693313       0
# 29  4.391936  1.028259 -1.727955  1.422879  2.166894       1
# 94  0.996055  1.714983 -0.150063 -1.596461 -1.477112       0
# 49  0.778859 -0.589193 -1.333947 -1.336577 -0.527541       0
# 61  0.693901 -0.831072 -2.238835  2.086753  0.892540       1
# 67  1.199809 -2.923468 -2.062041  3.115239  0.685752       1
# 89  1.309922  1.685748  0.467004  0.578238  1.233964       1
# ...

# %%
df1=sample_column(df,0.8)
# Out:
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']

# %%
df2=sample_column(df,0.8)
# Out:
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']

# %%
df3=sample_column(df,0.8)
df3
# Out:
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']
#            a         c         b         d  target
# 0   0.463418 -0.343536  0.030722  1.351243       1
# 1   1.767734 -1.122585  1.907874  0.771091       1
# 2   0.645799  0.033069  0.497108 -2.844073       0
# 3   1.763190 -0.450897  0.669100 -0.274788       0
# 4   0.934518 -2.306963  0.679429 -0.269605       0
# ..       ...       ...       ...       ...     ...
# 95  1.327962 -0.521503  0.524614 -0.702258       0
# 96  2.151113  1.842596 -0.394614 -2.201705       0
# 97 -0.481233 -2.056290 -1.421177 -4.989788       0
# 98  0.438720 -0.002318  1.925252  1.057133       1
# ...

# %%
df3.shape
# Out:
# (100, 5)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:4],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:4],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:4],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.39285714285714285, 0.9166666666666666, 'x[2] <= -0.193\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.14285714285714285, 0.75, 'x[3] <= -0.338\ngini = 0.219\nsamples = 48\nvalue = [42, 6]'),
#  Text(0.07142857142857142, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21428571428571427, 0.5833333333333334, 'x[0] <= 0.841\ngini = 0.087\nsamples = 44\nvalue = [42, 2]'),
#  Text(0.14285714285714285, 0.4166666666666667, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]'),
#  Text(0.2857142857142857, 0.4166666666666667, 'x[1] <= 0.261\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.21428571428571427, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35714285714285715, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6428571428571429, 0.75, 'x[0] <= -0.818\ngini = 0.26\nsamples = 52\nvalue = [8, 44]'),
#  Text(0.5714285714285714, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.4, 0.9375, 'x[1] <= -0.193\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.2, 0.8125, 'x[3] <= -0.338\ngini = 0.219\nsamples = 48\nvalue = [42, 6]'),
#  Text(0.1, 0.6875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3, 0.6875, 'x[2] <= -2.065\ngini = 0.087\nsamples = 44\nvalue = [42, 2]'),
#  Text(0.2, 0.5625, 'x[0] <= 0.841\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.1, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3, 0.4375, 'x[1] <= -0.356\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4, 0.5625, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.6, 0.8125, 'x[0] <= -0.818\ngini = 0.26\nsamples = 52\nvalue = [8, 44]'),
#  Text(0.5, 0.6875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7, 0.6875, 'x[1] <= 0.491\ngini = 0.12\nsamples = 47\nvalue = [3, 44]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.2916666666666667, 0.9444444444444444, 'x[3] <= -0.104\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.1111111111111111, 0.8333333333333334, 'x[2] <= 2.48\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.05555555555555555, 0.7222222222222222, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.16666666666666666, 0.7222222222222222, 'x[3] <= -0.187\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1111111111111111, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2222222222222222, 0.6111111111111112, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4722222222222222, 0.8333333333333334, 'x[0] <= 0.619\ngini = 0.393\nsamples = 67\nvalue = [18, 49]'),
#  Text(0.4166666666666667, 0.7222222222222222, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.5277777777777778, 0.7222222222222222, 'x[2] <= 1.09\ngini = 0.487\nsamples = 43\nvalue = [18, 25]'),
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
df1
# Out:
# Index(['d', 'b', 'e', 'a', 'target'], dtype='object')
# Index(['d', 'e', 'c', 'a', 'target'], dtype='object')
# Index(['a', 'c', 'b', 'd', 'target'], dtype='object')
#            d         b         e         a  target
# 0   1.351243  0.030722  0.573291  0.463418       1
# 1   0.771091  1.907874  1.542618  1.767734       1
# 2  -2.844073  0.497108 -2.086931  0.645799       0
# 3  -0.274788  0.669100 -1.944087  1.763190       0
# 4  -0.269605  0.679429 -0.561931  0.934518       0
# ..       ...       ...       ...       ...     ...
# 95 -0.702258  0.524614 -1.571685  1.327962       0
# 96 -2.201705 -0.394614 -2.973955  2.151113       0
# 97 -4.989788 -1.421177  0.038938 -0.481233       0
# 98  1.057133  1.925252  2.655706  0.438720       1
# 99 -1.724551  2.103156  0.491639 -0.395826       0
#
# [100 rows x 5 columns]

# %%
clf1.predict(np.array([3.581036,-0.134152,0.108098,1.603868]).reshape(1,4))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([3.581036,-0.134152,0.108098,1.603868]).reshape(1,4))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([3.581036,-0.134152,0.108098,1.603868]).reshape(1,4))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
df1 = combined_sampling(df,0.5,0.5)
df2 = combined_sampling(df,0.5,0.5)
df3 = combined_sampling(df,0.5,0.5)
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (50, 3)
# (50, 3)
# (50, 3)
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['target'] = df['target']
# /var/folders/c5/j4xn8t9516b4npj80r2701bc0000gn/T/ipykernel_20657/1548313429.py:5: SettingWithCopyWarning:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
df1
# Out:
#            e         a  target
# 93 -1.541420  1.422401       0
# 80  1.425349  2.012547       1
# 74  0.014665  0.764901       1
# 90  1.164806  2.016034       1
# 95 -1.571685  1.327962       0
# 71 -0.359652  0.734534       0
# 4  -0.561931  0.934518       0
# 42  1.030959 -0.874259       1
# 48 -1.082921  1.335499       0
# 99  0.491639 -0.395826       0
# 68 -1.494091  1.862374       0
# 37 -0.695147  0.983442       0
# 31 -0.479384  0.827942       1
# 2  -2.086931  0.645799       0
# 18 -0.771214 -2.688769       1
# 51 -1.699874  0.050646       0
# 44 -1.336881  2.297714       0
# 75  1.100174 -1.303706       1
# 10 -1.268327  0.896875       0
# 0   0.573291  0.463418       1
# 38 -0.750877  1.132947       0
# 21  2.523557  2.830940       1
# 26  1.144515  2.385200       1
# 54  0.563989 -0.321111       0
# 59  0.293869  3.254847       1
# 43 -1.481275 -0.131088       0
# 29  2.166894  4.391936       1
# 50  4.558157  1.381493       1
# 79 -0.840468 -0.766312       1
# ...

# %%
clf1.predict(np.array([-0.664676,-0.339432]).reshape(1,2))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([-0.664676,-0.339432]).reshape(1,2))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-0.664676,-0.339432]).reshape(1,2))
# Out:
# /Users/spydee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= -0.193\ngini = 0.493\nsamples = 50\nvalue = [22, 28]'),
#  Text(0.16666666666666666, 0.75, 'x[1] <= -0.449\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(0.08333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25, 0.5833333333333334, 'x[0] <= -0.684\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[0] <= -0.42\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.25, 0.25, 'x[1] <= 0.881\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4166666666666667, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[0] <= 0.554\ngini = 0.499\nsamples = 50\nvalue = [24, 26]'),
#  Text(0.2222222222222222, 0.75, 'x[1] <= 1.772\ngini = 0.302\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.1111111111111111, 0.5833333333333334, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'x[0] <= -0.302\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4444444444444444, 0.4166666666666667, 'x[1] <= 2.791\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5555555555555556, 0.25, 'x[1] <= 3.469\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4444444444444444, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...
