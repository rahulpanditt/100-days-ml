# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# from sklearn.pipeline import Pipeline

# %%
x = 6 * np.random.rand(200,1)-3
y = 0.8 * x**2 + 0.9*x + 2 + np.random.randn(200,1)

# %%
plt.plot(x,y,'b.')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,random_state=2,test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.2786965559494796

# %%
plt.plot(X_train,lr.predict(X_train),color='r')
plt.plot(x,y,'b.')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
## Polynomial Regression
poly = PolynomialFeatures(degree=2,include_bias=True)
X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test) 
#ensure that we apply transformation on both train and test data and not at y at all;

# %%
print(X_train[0])
print(X_train_trans[0])
# Out:
# [-1.54153716]
# [ 1.         -1.54153716  2.37633683]

# %%
lr = LinearRegression()
lr.fit(X_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trans)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8681480723610714

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[0.         0.97368246 0.77697171]]
# [2.03705793]

# %%
x_new = np.linspace(-3,3,200).reshape(200,1)
x_new_poly = poly.transform(x_new)
y_new=lr.predict(x_new_poly)

# %%
plt.plot(x_new,y_new,'r-',linewidth=2,label='Predictions')
plt.plot(X_train,y_train,'b.',label='Training Points')
plt.plot(X_test,y_test,'g.',label="Testing Points")
plt.legend
plt.show()

# %%
x = 6 * np.random.rand(200,1)-3
y = 0.8 * x**2 + 0.9*x + 2 + np.random.randn(200,1)

# %%
# plt.scatter(x,y)
plt.plot(x,y,'.')
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.plot(X_train,lr.predict(X_train),'r')
plt.plot(X_train,y_train,'.')

# %%
poly = PolynomialFeatures(degree=2,include_bias=True)
X_train_poly = poly.fit_transform(X_train)
X_test = poly.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 3
#       1 poly = PolynomialFeatures(degree=2,include_bias=True)
#       2 X_train_poly = poly.fit_transform(X_train)
# ----> 3 X_test = poly.transform(X_test)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_polynomial.py:341, in PolynomialFeatures.transform(self, X)
#     311 """Transform data to polynomial features.
#     312
#     313 Parameters
#    (...)
#     337     `csr_matrix`.
#     338 """
#     339 check_is_fitted(self)
# --> 341 X = self._validate_data(
#     342     X, order="F", dtype=FLOAT_DTYPES, reset=False, accept_sparse=("csr", "csc")
#     343 )
#     345 n_samples, n_features = X.shape
#     347 if sparse.isspmatrix_csr(X):
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:588, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
# --> 588     self._check_n_features(X, reset=reset)
#     590 return out
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:389, in BaseEstimator._check_n_features(self, X, reset)
#     386     return
#     388 if n_features != self.n_features_in_:
# --> 389     raise ValueError(
#     390         f"X has {n_features} features, but {self.__class__.__name__} "
#     391         f"is expecting {self.n_features_in_} features as input."
#     392     )
#
# ValueError: X has 3 features, but PolynomialFeatures is expecting 1 features as input.
