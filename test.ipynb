# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
x = 6 * np.random.rand(200,1)-3
y = 0.5 * x**2 + 0.9*x + 2 + np.random.rand(200,1)

# %%
plt.plot(x,y,'.b')

# %%
lr = LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,random_state=2,test_size=0.2)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.plot(X_train,lr.predict(X_train),'red')
plt.plot(x,y,'.b')

# %%
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.48066272160446555

# %%
poly = PolynomialFeatures(degree=3,include_bias=True)
x_train = poly.fit_transform(X_train)
x_test = poly.transform(X_test)

# %%
print(x_train[0])
print(x_test[0])
# Out:
# [ 1.          2.26736491  5.14094365 11.65639526]
# [ 1.          2.85361838  8.14313787 23.2374079 ]

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_new = lr.predict(x_test)

# %%
r2_score(y_test,y_new)
# Out:
# 0.974395193801462

# %%
a = np.linspace(-3,3,200).reshape(200,1)
a_new = poly.transform(a)
b = lr.predict(a_new)

# %%
plt.plot(a,b,'r-')
plt.plot(x,y,'.b')

# %%
a =[1,2,3,4,5,6]
a = np.array(a)
print(a*2)
# Out:
# [ 2  4  6  8 10 12]
